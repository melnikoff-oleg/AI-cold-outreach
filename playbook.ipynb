# %%
from openai import OpenAI
import requests
import os

openai_client = OpenAI(api_key=os.getenv("OPENAI_TOKEN"))

# profile_url = 'https://www.linkedin.com/in/nycgareth/'
# profile_url = 'https://www.linkedin.com/in/salikhovkamil/'
# profile_url = 'https://www.linkedin.com/in/roman-ageev-ai/'
profile_url = 'https://www.linkedin.com/in/gustjuarez/'


headers = {'Authorization': 'Bearer ' + os.getenv("PROXYCURL_TOKEN")}
api_endpoint = 'https://nubela.co/proxycurl/api/v2/linkedin'
params = {'url': profile_url}
person_profile = requests.get(api_endpoint, params=params, headers=headers).json()
api_endpoint = 'https://nubela.co/proxycurl/api/linkedin/company'
params = {'url': person_profile['experiences'][0]['company_linkedin_profile_url']}
company_profile = requests.get(api_endpoint, params=params, headers=headers).json()

# %%
person_profile
# Out:
# {'public_identifier': 'gustjuarez',
#  'profile_pic_url': 'https://media.licdn.com/dms/image/v2/C5603AQGAMJRuNBOn0A/profile-displayphoto-shrink_800_800/profile-displayphoto-shrink_800_800/0/1577143475417?e=1733356800&v=beta&t=xXfyEBsFJ3El1274hbyFPHxf55hROrtrZ_AQZ2SAARw',
#  'background_cover_image_url': 'https://media.licdn.com/dms/image/v2/D5616AQFLetkUufNVzw/profile-displaybackgroundimage-shrink_350_1400/profile-displaybackgroundimage-shrink_350_1400/0/1713179819237?e=1733356800&v=beta&t=O02-l8L5ui5U35s-Ch0X5teZJekSimuE7bRVmFuK2WU',
#  'first_name': 'Gustavo',
#  'last_name': 'Juárez Ugarte',
#  'full_name': 'Gustavo Juárez Ugarte',
#  'follower_count': 1815,
#  'occupation': 'VP of Engineering and Manufacturing at Quatt',
#  'headline': 'Vice President of Engineering and Manufacturing',
#  'summary': "I am a results-oriented engineer with a passion for vehicle product development, clean energies, and the teams that drive them forward. Throughout my professional experience, I have been involved in the entire lifecycle of product development, from defining requirements and detail-design to validating and introducing products to the market.\n\nI have consistently demonstrated my ability to deliver excellent results, starting from my academic background. I thrive in complex situations and always strive to add value.\n\nWith a skillset that encompasses engineering, a business mindset, and managerial skills, I am confident in my ability to tackle any challenge, whether it's technical or strategic in nature.\n\nWhile I take great pride in my own work, I place even greater emphasis on the teams behind the projects I lead. My ultimate goal is to establish a lean organization that prioritizes people, ensuring highly efficient and motivated teams that serve as the backbone of innovative product development.\n\nCertifications:\n\nPMP Project Management Professional\nDesign for Six Sigma: Black Belt\nReliability Engineering: Black Belt",
#  'country': 'NL',
#  'country_full_name': 'Netherlands',
#  'city': 'Amsterdam',
#  'state': 'North Holland',
#  'experiences': [{'starts_at': {'day': 1, 'month': 3, 'year': 2024},
#    'ends_at': None,
#    'company': 'Quatt',
#    'company_linkedin_profile_url': 'https://www.linkedin.com/company/quatt-heat',
#    'company_facebook_profile_url': None,
#    'title': 'VP of Engineering and Manufacturing',
#    'description': None,
#    'location': 'Amsterdam, Nordholland, Niederlande',
#    'logo_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/company/quatt-heat/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20241001%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20241001T075759Z&X-Amz-Expires=1800&X-Amz-SignedHeaders=host&X-Amz-Signature=108a3087d42c6a7dbff6ca6a9f4cb9de84f9ace29a229fbf998bb0d11c9c69ff'},
#   {'starts_at': {'day': 1, 'month': 9, 'year': 2023},
#    'ends_at': {'day': 31, 'month': 3, 'year': 2024},
#    'company': 'Dott',
#    'company_linkedin_profile_url': 'https://www.linkedin.com/company/ridedott',
#    'company_facebook_profile_url': None,
#    'title': 'VP of Vehicle Product',
#    'description': None,
#    'location': 'Amsterdam, Nordholland, Niederlande',
#    'logo_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/company/ridedott/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20241001%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20241001T075759Z&X-Amz-Expires=1800&X-Amz-SignedHeaders=host&X-Amz-Signature=9482ced4ae7ed17e1e3a1c491bc121432023b3c6c14d2f50e0923e033ced1740'},
#   {'starts_at': {'day': 1, 'month': 7, 'year': 2021},
#    'ends_at': {'day': 30, 'month': 9, 'year': 2023},
#    'company': 'Dott',
#    'company_linkedin_profile_url': 'https://www.linkedin.com/company/ridedott',
#    'company_facebook_profile_url': None,
#    'title': 'Vehicle Engineering & Manufacturing Director',
#    'description': 'Team & growth:\n-Functional manager for the Vehicle Engineering (Mechanics, Electronics, Powertrain, Embedded Software and Back-End), Manufacturing, Supply Chain, Procurement and Quality Departments. Scale the team from 15 to 50 FTE’s. \n-Build a cross functional matrix organization to manage multiple simultaneous projects. \n-Department administrative topics: resource management, department and individual goals definitions among others. \n\nProduct Development:\n-Responsible for the vehicle engineering of our own developed eScooter (steps) and eBikes following a vertical integration strategy.\n-Definition of high level specifications of the vehicles for the EU market.\n-Developed engineering-, product lifecycle-, quality- and supply chain processes to support the development of our vehicles.\n-Support on the improvement of OTS spare parts \n\nSustaining Fleet & Availability:\n-Supported the acquisition of new vehicles and negotiations with suppliers (pricing, warranties etc).\n-Supported E2E the availability of vehicles and spare parts and their distribution to markets.\n-Support on the launch of new vehicles and/or markets \n-Support on the resolution of quality issues from OTS vehicle suppliers',
#    'location': 'Amsterdam, Nordholland, Niederlande',
#    'logo_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/company/ridedott/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20241001%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20241001T075759Z&X-Amz-Expires=1800&X-Amz-SignedHeaders=host&X-Amz-Signature=9482ced4ae7ed17e1e3a1c491bc121432023b3c6c14d2f50e0923e033ced1740'},
#   {'starts_at': {'day': 1, 'month': 7, 'year': 2018},
#    'ends_at': {'day': 30, 'month': 6, 'year': 2021},
#    'company': 'Ola Electric Mobility Pvt. Ltd.',
#    'company_linkedin_profile_url': 'https://www.linkedin.com/company/olaelectric',
#    'company_facebook_profile_url': None,
#    'title': 'Director l Chief Engineer',
#    'description': "Etergo B.V. (from Juli 2018 - June 2020) - Engineering Manager | VPM\nOla Electric (June 2020 - July 2021) - Chief Engineer\n\nLeading the complete development and operations of the smart electric Etergo AppScooter (today Ola Electric S1) from concept definition up to European homologation and manufacturing readiness.\n\nLed and scale a team of 60 FTE's in different disciplines:\n-Scale and manage a multi-disciplinary engineering team: Vehicle Design, Systems-, Hardware-, Software-, UX/UI-, Mechanics-, Service- and Powertrain engineering, Prototype build, Homologation and Engineering Project Management.\n-Responsible for managing all activities for the Supply chain, Procurement, Quality, and Manufacturing departments. Also main contact for Finance, Legal and Go-to-Market teams.\n-Ressource, Performance and Career Development management.\n\nDeveloped processes from scratch in fast-paced environment:\n-Developed the product strategy and product roadmap\n-Product life cycle management to support vehicle development activities such as quality gates, requirements engineering, part numbering systems & BOM management, root cause analysis tools, lessons learned,Design for Six Sigma and reliability engineering among others.\n-Developed procurement processes for strategic sourcing of components at vehicle level (RfQ packages, cost breakdown analysis, supplier quality among others)\n-Project management processes such as Time-, Risk-, Change-and Budget management.\n-Responsible for all vehicle validation acc. to automotive standards. The vehicle was designed and validated for a lifetime of 100kkm on European roads.\n\nSupported business owners in acquisition of Etergo to Ola Electric\n-Main technical contact for Ola electric during acquisition phase\n-Supported all business activities, specially during the product due diligence.\n-Created all product related financial projections for the AppScooter as well as future European product roadmap.",
#    'location': 'Amsterdam, Nordholland, Niederlande',
#    'logo_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/company/olaelectric/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20241001%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20241001T075759Z&X-Amz-Expires=1800&X-Amz-SignedHeaders=host&X-Amz-Signature=c923dbcb460fa2e24b858a30de35e6565ca3d8f230fa4660e8fc830c428036c4'},
#   {'starts_at': {'day': 1, 'month': 2, 'year': 2014},
#    'ends_at': {'day': 30, 'month': 6, 'year': 2018},
#    'company': 'Continental',
#    'company_linkedin_profile_url': 'https://www.linkedin.com/company/continental',
#    'company_facebook_profile_url': None,
#    'title': 'Project Manager Engineering / System technical project leader',
#    'description': 'Business Unit Transmission\n-Responsible for the technical development and global engineering of the Renault/Nissan E-Tech Hybrid gearbox actuator.\n-Responsible for the design and technical concept (Clarification of stakeholder requests and system requirements engineering).\n-Lead of a large international engineering team (including System, Hardware, Software, Mechanics). \n-Ensure the utilisation of Design for Six Sigma and Reliability engineering during development.\n-Lead of engineering change management. \n-Main contact for customer technical communication.\n-Main contact for supplier communication and technical supplier selection.\n-Main contact between engineering and quality, manufacturing, purchasing and other internal departments.\n-Planning and coordination of development. (Planning of resources, costs and time)\n-Responsible for system testing planning and qualification.',
#    'location': 'Nürnberg und Umgebung, Deutschland',
#    'logo_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/company/continental/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20241001%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20241001T075759Z&X-Amz-Expires=1800&X-Amz-SignedHeaders=host&X-Amz-Signature=2a36d2abb5589d6b140aa9ec214f0411bfcd6f40c1b901d40420f5c5f1421988'},
#   {'starts_at': {'day': 1, 'month': 2, 'year': 2013},
#    'ends_at': {'day': 31, 'month': 1, 'year': 2014},
#    'company': 'Continental',
#    'company_linkedin_profile_url': 'https://www.linkedin.com/company/continental',
#    'company_facebook_profile_url': None,
#    'title': 'Mechanical project manager',
#    'description': 'Business Unit Transmission\nResponsible for development of mechanical design concepts for transmission control units based on customer requirements list.\n  -Coordination of mechanical design team \n  -Creation of CAD Models with Pro-Engineer\n  -Participation in FMEA \n  -Time planning for mechanical concept\n  -Test concept creation\n  -Design based on DfSS (Design for Six Sigma)\n  -Design optimisation based on FEM simulation ',
#    'location': 'Nürnberg Area, Germany',
#    'logo_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/company/continental/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20241001%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20241001T075759Z&X-Amz-Expires=1800&X-Amz-SignedHeaders=host&X-Amz-Signature=2a36d2abb5589d6b140aa9ec214f0411bfcd6f40c1b901d40420f5c5f1421988'},
#   {'starts_at': {'day': 1, 'month': 6, 'year': 2012},
#    'ends_at': {'day': 31, 'month': 1, 'year': 2013},
#    'company': 'Continental',
#    'company_linkedin_profile_url': 'https://www.linkedin.com/company/continental',
#    'company_facebook_profile_url': None,
#    'title': 'Mechanical Design & Technology',
#    'description': 'Continental Automotive Graduate Program (DRIVE) / Business Unit Engine Systems:\n-Responsible for design and qualification of different insulation concepts for engine control units\n-Development of qualification test plan, test coordination and analysis of results for several insulation concepts\n-Validation of supplier changes notifications (impact analysis, qualification test plan development and validation of results)\n-Development of mechanical design concepts for request of quotations of engine control units\n-investigation on high thermal conductivity materials.\n\n\n',
#    'location': 'Toulouse Area, France',
#    'logo_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/company/continental/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20241001%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20241001T075759Z&X-Amz-Expires=1800&X-Amz-SignedHeaders=host&X-Amz-Signature=2a36d2abb5589d6b140aa9ec214f0411bfcd6f40c1b901d40420f5c5f1421988'},
#   {'starts_at': {'day': 1, 'month': 10, 'year': 2011},
#    'ends_at': {'day': 31, 'month': 5, 'year': 2012},
#    'company': 'Continental',
#    'company_linkedin_profile_url': 'https://www.linkedin.com/company/continental',
#    'company_facebook_profile_url': None,
#    'title': 'Mechanical platform design',
#    'description': "Continental Automotive Graduate Program (DRIVE) / Business Unit Engine Systems.\n-Responsible for analysis of insulation coordination normatives for Engine Control units\n-Creation of insulation concepts for ECU's\n-Creation of requirements for insulation coordination topics to suppliers\n-Support for PCB qualifications and quality topics\n",
#    'location': 'Regensburg Area, Germany',
#    'logo_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/company/continental/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20241001%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20241001T075759Z&X-Amz-Expires=1800&X-Amz-SignedHeaders=host&X-Amz-Signature=2a36d2abb5589d6b140aa9ec214f0411bfcd6f40c1b901d40420f5c5f1421988'},
#   {'starts_at': {'day': 1, 'month': 10, 'year': 2010},
#    'ends_at': {'day': 31, 'month': 7, 'year': 2011},
#    'company': 'Aupro Water Systems',
#    'company_linkedin_profile_url': None,
#    'company_facebook_profile_url': None,
#    'title': 'Design engineer of water treatment plants',
#    'description': 'Research and Development, Schamlkalden, Thüringen\t\nResponsible for:\n-CAD Design of the actual Aqua4Life 24 (24 000 l/Day) and optimization of the lay out\n-CAD Design of the new Aqua4Life 60 (60 000 l/Day)\n-Concept development  for the Aqua4Life “Baby - machine” (6 000 l /Tag)\n-Technical documentation for the water treatment plants\n-Market analysis and their possibilities in USA and Mexico\n-General Office work',
#    'location': 'Erfurt und Umgebung, Deutschland',
#    'logo_url': None},
#   {'starts_at': {'day': 1, 'month': 4, 'year': 2010},
#    'ends_at': {'day': 31, 'month': 10, 'year': 2010},
#    'company': 'Enders + Sigeti GmbH',
#    'company_linkedin_profile_url': None,
#    'company_facebook_profile_url': None,
#    'title': 'Design engineer of small wind turbines',
#    'description': 'Note: 1,3\nMaster Thesis:Product development of a vertical axis wind turbine with rated power of 5kW; Design, optimisation and construction.\nActivities performed during the master thesis:\n-Patents research\n-Design and development of different vertical axis Wind Turbines\n-Analysis of the geometry of the rotors within their efficiency optimization through CFD (Control Fluid Dynamics) Analysis\n-Prove of the calculated geometries through Rapid Prototyping Mock-ups on a wind channel\n-Material selection, criteria: Stiffness, density, life cycle, recyclability and costs\n-Bearing calculation\n-Technical review of the selected geometry through FEM Analysis under the consideration of the IEC 61400-2 Standard.\n-Design and development of the VAWT with helicoidally blades\n-Design and development of the mounting frame\n-Technical review of the designed mounting frame through FEM Analysis under the consideration of the IEC 61400-2 Standard\n-Cost calculation\n-Technical documentation',
#    'location': 'Erfurt und Umgebung, Deutschland',
#    'logo_url': None},
#   {'starts_at': {'day': 1, 'month': 4, 'year': 2009},
#    'ends_at': {'day': 28, 'month': 2, 'year': 2010},
#    'company': 'NPTEC GmbH',
#    'company_linkedin_profile_url': None,
#    'company_facebook_profile_url': None,
#    'title': 'Design engineer of small wind turbines',
#    'description': 'Technical Review and optimization of Small Wind Turbines\n\nDuring this time, the following tasks were done: \n\nProject: Herkules Wind Turbine (7,5 kW Type American Windmill)\n\n- Design of all the components of the wind turbine (From fundament to blades)\n- Optimization of the blades through FEM Analysis under the consideration of the Germanischen Lloyd Standard. \n- Material selection; Criterion: Stiffness, density, life cycle, recyclability and costs \n- Selection of a slow speed generator in order to avoid the utilization of a gearbox\n- Bearing calculation  from  the main shaft and the Azimuth bearing\n- Determination of Assembling and tilt-up technologies.',
#    'location': 'Erfurt und Umgebung, Deutschland',
#    'logo_url': None},
#   {'starts_at': {'day': 1, 'month': 4, 'year': 2009},
#    'ends_at': {'day': 31, 'month': 8, 'year': 2009},
#    'company': 'LEONI',
#    'company_linkedin_profile_url': 'https://www.linkedin.com/company/leoni',
#    'company_facebook_profile_url': None,
#    'title': 'Support in customer center',
#    'description': 'During this time, the following tasks were done:\n•\tSupport in supply chain processes\n•\tGeneral support in customer center\n\nProject: Business process analysis in LEONI Barcelona factory\n•\tAnalysis and documentation of the working processes in the Spanish factory\n•\tComparison between the Spanish and German core business processes\n•\tOptimization, and standardisation possibilities given',
#    'location': 'Erfurt und Umgebung, Deutschland',
#    'logo_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/company/leoni/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20241001%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20241001T075759Z&X-Amz-Expires=1800&X-Amz-SignedHeaders=host&X-Amz-Signature=c044016a078211898c25dcafa2c76114289be7e93a462c0492813d74f403810e'},
#   {'starts_at': {'day': 1, 'month': 10, 'year': 2008},
#    'ends_at': {'day': 30, 'month': 4, 'year': 2009},
#    'company': 'LEONI',
#    'company_linkedin_profile_url': 'https://www.linkedin.com/company/leoni',
#    'company_facebook_profile_url': None,
#    'title': 'Process Reengineering',
#    'description': 'Note: 1,0\nDiploma thesis: “Process visualization and optimization of all core business processes of the Customer Center within a framework of a process oriented, operational and organized structure”\t\nDuring this time the following activities were done:\n\n- Documentation of the actual business processes and organisation of the company\n- Development of a mathematical node system based on Six Sigma/DMAIC and TOC methodologies\n- Simulation of the business processes\n- Calculation and determination of the Time-to-Market\n- Found out of the Bottle necks and critical processes of the company\n- Planning and controlling of optimization possibilities for the intern processes\n',
#    'location': 'Erfurt Area, Germany',
#    'logo_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/company/leoni/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20241001%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20241001T075759Z&X-Amz-Expires=1800&X-Amz-SignedHeaders=host&X-Amz-Signature=c044016a078211898c25dcafa2c76114289be7e93a462c0492813d74f403810e'},
#   {'starts_at': {'day': 1, 'month': 4, 'year': 2008},
#    'ends_at': {'day': 31, 'month': 8, 'year': 2008},
#    'company': 'BASF',
#    'company_linkedin_profile_url': 'https://www.linkedin.com/company/basf',
#    'company_facebook_profile_url': None,
#    'title': 'Chemical procurement',
#    'description': 'Internship\nDuring this time, the following tasks were done: \n- Raw material procurer\n- Optimization of the logistic of transit documentation of  raw material \n- Support in the Intranet documentation\n\nProject: Cost reduction of pallets in the factory in Altamira\n- Analysis of the possibilities to ensure a successful reduction of the pallets in the Altamira’s warehouse\n- Controlling of over 100 suppliers In- and in foreign countries for making a standardization of the type of pallets in which the material was send on\n\nProject: Suppliers evaluation\n- Analysis of the actual supplier’s evaluation system\n- Development and improvement of the evaluations system\n- Suppliers evaluation\n',
#    'location': 'Mexico City Area, Mexico',
#    'logo_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/company/basf/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20241001%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20241001T075759Z&X-Amz-Expires=1800&X-Amz-SignedHeaders=host&X-Amz-Signature=83788ba9189615d77b152aded1ddbcc0ee1cd847ffa54c9a72bf4422819863f0'}],
#  'education': [{'starts_at': {'day': 1, 'month': 1, 'year': 2009},
#    'ends_at': {'day': 31, 'month': 12, 'year': 2011},
#    'field_of_study': 'Product development and innovations',
#    'degree_name': 'Master in Mechanical Engineering',
#    'school': 'Hochschule Schmalkalden',
#    'school_linkedin_profile_url': 'https://www.linkedin.com/company/12216362/',
#    'school_facebook_profile_url': None,
#    'description': "The aim of this Master's program is the in-depth knowledge of theoretical mechanical design theory, modern techniques and development tools in the process of development and design of new products. It also integrates modern manufacturing technology and assembly processes knowledge.\n",
#    'logo_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/company/schmalkalden-university/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20241001%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20241001T075759Z&X-Amz-Expires=1800&X-Amz-SignedHeaders=host&X-Amz-Signature=9163c288d3bf8884c61da3716338090474ca3aab615d9db0abc0efda4af0b179',
#    'grade': '2,0',
#    'activities_and_societies': None},
#   {'starts_at': {'day': 1, 'month': 1, 'year': 2008},
#    'ends_at': {'day': 31, 'month': 12, 'year': 2009},
#    'field_of_study': 'Mechatronik, Robotik und Automatisierungstechnik',
#    'degree_name': 'Master in Advanced Manufacturing Systems',
#    'school': 'Universidad Panamericana',
#    'school_linkedin_profile_url': 'https://www.linkedin.com/company/234524/',
#    'school_facebook_profile_url': None,
#    'description': None,
#    'logo_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/company/universidad-panamericana/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20241001%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20241001T075759Z&X-Amz-Expires=1800&X-Amz-SignedHeaders=host&X-Amz-Signature=1fd0503be2cdf314de499de2c85fa55ce8047a8894af20126121afb112398780',
#    'grade': '1,7',
#    'activities_and_societies': None},
#   {'starts_at': {'day': 1, 'month': 1, 'year': 2004},
#    'ends_at': {'day': 31, 'month': 12, 'year': 2008},
#    'field_of_study': 'Mechatronik, Robotik und Automatisierungstechnik',
#    'degree_name': 'Diploma in mechatronics',
#    'school': 'Universidad Panamericana',
#    'school_linkedin_profile_url': 'https://www.linkedin.com/company/234524/',
#    'school_facebook_profile_url': None,
#    'description': None,
#    'logo_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/company/universidad-panamericana/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20241001%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20241001T075759Z&X-Amz-Expires=1800&X-Amz-SignedHeaders=host&X-Amz-Signature=1fd0503be2cdf314de499de2c85fa55ce8047a8894af20126121afb112398780',
#    'grade': '1,7',
#    'activities_and_societies': None}],
#  'languages': ['Deutsch',
#   'Englisch',
#   'Französisch',
#   'Niederländisch',
#   'Spanisch'],
#  'languages_and_proficiencies': [{'name': 'Deutsch',
#    'proficiency': 'FULL_PROFESSIONAL'},
#   {'name': 'Englisch', 'proficiency': 'FULL_PROFESSIONAL'},
#   {'name': 'Französisch', 'proficiency': 'LIMITED_WORKING'},
#   {'name': 'Niederländisch', 'proficiency': 'ELEMENTARY'},
#   {'name': 'Spanisch', 'proficiency': 'NATIVE_OR_BILINGUAL'}],
#  'accomplishment_organisations': [],
#  'accomplishment_publications': [],
#  'accomplishment_honors_awards': [],
#  'accomplishment_patents': [],
#  'accomplishment_courses': [],
#  'accomplishment_projects': [],
#  'accomplishment_test_scores': [],
#  'volunteer_work': [],
#  'certifications': [{'starts_at': {'day': 1, 'month': 11, 'year': 2016},
#    'ends_at': {'day': 30, 'month': 11, 'year': 2022},
#    'name': 'Project Management Professional (PMP)',
#    'license_number': '1983010',
#    'display_source': None,
#    'authority': 'Project Management Institute',
#    'url': None},
#   {'starts_at': {'day': 1, 'month': 10, 'year': 2014},
#    'ends_at': None,
#    'name': 'Design for Six Sigma: GreenBelt',
#    'license_number': None,
#    'display_source': None,
#    'authority': 'innovensys',
#    'url': None},
#   {'starts_at': {'day': 1, 'month': 3, 'year': 2016},
#    'ends_at': None,
#    'name': 'Reliability Green Belt',
#    'license_number': None,
#    'display_source': None,
#    'authority': 'Universität Stuttgart',
#    'url': None},
#   {'starts_at': {'day': 1, 'month': 12, 'year': 2017},
#    'ends_at': None,
#    'name': 'Design for Six Sigma: Black Belt',
#    'license_number': '50-2017',
#    'display_source': None,
#    'authority': 'innovensys',
#    'url': None},
#   {'starts_at': {'day': 1, 'month': 12, 'year': 2018},
#    'ends_at': None,
#    'name': 'Reliability Engineering Black Belt',
#    'license_number': None,
#    'display_source': 'reliability-academy.de',
#    'authority': 'Universität Stuttgart',
#    'url': 'https://reliability-academy.de/de/zuverlaessigkeitsingenieur/reliability-black-belt/index.html'}],
#  'connections': 1779,
#  'people_also_viewed': [{'link': 'https://www.linkedin.com/in/willjohnsonuk',
#    'name': 'Will Johnson',
#    'summary': 'Electronic Engineer working in Micromobility | Senior Vehicle Systems Engineer at Dott',
#    'location': None},
#   {'link': 'https://www.linkedin.com/in/marienjomier',
#    'name': 'Marien Jomier',
#    'summary': 'Regional Director - North Europe chez Dott',
#    'location': None},
#   {'link': 'https://www.linkedin.com/in/maxim-romain-28b23b5',
#    'name': 'Maxim Romain',
#    'summary': 'COO & Co-Founder @ dott',
#    'location': None},
#   {'link': 'https://www.linkedin.com/in/oier-kaltzakorta',
#    'name': 'Oier Kaltzakorta',
#    'summary': 'Product development | Electrification | Project Management',
#    'location': None},
#   {'link': 'https://www.linkedin.com/in/katya-volkava-a00208172',
#    'name': 'Katya Volkava',
#    'summary': 'Senior Business Strategy Manager at Dott',
#    'location': None},
#   {'link': 'https://www.linkedin.com/in/michael-ventouris',
#    'name': 'Michael Ventouris',
#    'summary': 'General Manager - London at Dott',
#    'location': None},
#   {'link': 'https://www.linkedin.com/in/clairemai',
#    'name': 'Claire Mai',
#    'summary': 'Making our teams in Engineering, Product and Finance enjoy their ride at Dott! 🛴',
#    'location': None},
#   {'link': 'https://www.linkedin.com/in/jose-luis-gil-gonzalez-22094a83',
#    'name': 'Jose Luis Gil Gonzalez',
#    'summary': 'Malaga City Manager en Dott',
#    'location': None},
#   {'link': 'https://www.linkedin.com/in/daniela-santos-170a08103',
#    'name': 'Daniela Santos',
#    'summary': 'Project Quality Manager at Dott || Aeronautical Engineer',
#    'location': None},
#   {'link': 'https://www.linkedin.com/in/jorge-díaz-fontenla',
#    'name': 'Jorge Díaz Fontenla',
#    'summary': 'Area Manager, Spain @ dott',
#    'location': None}],
#  'recommendations': ["Maarten van der Heide\n\n\n\nGustavo is an incredibly talented and motivating product development leader who truly understands how to design and execute great products, drive efficient processes, and most importantly build amazing teams. \nI've had the pleasure of working with Gustavo since late 2021 where he has led multiple functions under the Vehicle Product Team, including development, supply chain, manufacturing and others. Gustavo's calm, clear,  and human approach to issues and solutions (both on projects and with teams) allows for focused and efficient navigation of even the most complex situations. He is trusted by both his teams, and his stakeholders.  He is an invaluable asset to any team or venture he chooses to pursue and I look forward to continuing to support his journey!"],
#  'activities': [{'title': 'New challlengeAfter a period in product development, consultancy and business development, where I learned a lot on conceptual design en design…',
#    'link': 'https://www.linkedin.com/posts/jeroen-kuiper-4b404b16_new-challlenge-after-a-period-in-product-activity-7094064419764097024-wmck',
#    'activity_status': 'Gemarkeerd als interessant door Gustavo Juárez Ugarte'},
#   {'title': "Doesn't smell gasoline.Learn more about the core initiatives at CAKE, the story behind and the coming future, to speed up towards our mission - 'To…",
#    'link': 'https://www.linkedin.com/posts/cake-%E2%80%93-ridecake%2Ecom_explorewithrespect-activity-7091819959969808385-ur52',
#    'activity_status': 'Gemarkeerd als interessant door Gustavo Juárez Ugarte'},
#   {'title': 'Great to see the adoption of #lekkerbikes in the German market. Our most recent product review in the #Süddeutschezeiting shows that our design…',
#    'link': 'https://www.linkedin.com/posts/niels-bark-62973a10_urbane-mobilit%C3%A4t-wie-radfahren-in-st%C3%A4dten-activity-7082363418728353792-M7S2',
#    'activity_status': 'Gemarkeerd als interessant door Gustavo Juárez Ugarte'},
#   {'title': 'Very pleased that Dott will continue to be part of Transport for London and London Councils e-scooter operation in London. Well done to the Dott…',
#    'link': 'https://www.linkedin.com/posts/duncan-robertson-5630a7b_dott-lime-and-voi-win-london-e-scooter-contract-activity-7082093823580856320-QRnF',
#    'activity_status': 'Gemarkeerd als interessant door Gustavo Juárez Ugarte'},
#   {'title': 'Makka Polestar edition. The electric revolution is accelerating faster than one could have ever imagined - cars are progressively being banned from…',
#    'link': 'https://www.linkedin.com/posts/cake-%E2%80%93-ridecake%2Ecom_cakexpolestar-polestarcars-ohlinsracing-activity-7080516012936171520-PR4T',
#    'activity_status': 'Gemarkeerd als interessant door Gustavo Juárez Ugarte'},
#   {'title': "We are building the world's cleanest motorcycle by 2025.Possibly reducing the carbon footprint from aluminium with 77-97%Together with Norsk Hydro…",
#    'link': 'https://www.linkedin.com/posts/isabella-pehrsson-3a7a0042_cleanestdirtbikeever-activity-7077621261203382272-MQOC',
#    'activity_status': 'Gemarkeerd als interessant door Gustavo Juárez Ugarte'},
#   {'title': 'An important step to strengthen Polestar’s position in China.Local for Local and addressing market requirements directly to a local operation team…',
#    'link': 'https://www.linkedin.com/posts/joerg-brandscheid-06786658_polestar-partners-with-geelys-meizu-to-build-activity-7076488214521245696-WTp-',
#    'activity_status': 'Gemarkeerd als interessant door Gustavo Juárez Ugarte'},
#   {'title': "In 2016 Kendall took the maiden voyage for FTN Motion and confused the hell out of some Pukekohe residents. Seven years on, we've got an awesome team…",
#    'link': 'https://www.linkedin.com/posts/luke-sinclair-51236149_in-2016-kendall-took-the-maiden-voyage-for-activity-7077037299489787904-9tnE',
#    'activity_status': 'Gemarkeerd als interessant door Gustavo Juárez Ugarte'},
#   {'title': 'CNN on CAKELink in comments',
#    'link': 'https://www.linkedin.com/posts/stefan-ytterborn-164b63112_cnn-on-cake-link-in-comments-activity-7072890647971602432-bp-Y',
#    'activity_status': 'Gemarkeerd als interessant door Gustavo Juárez Ugarte'},
#   {'title': 'I am thrilled to share the news of our new Canyon App launch! I would like to express my gratitude to Michiel Ooms, Lionel Guicherd-Callin and Luz…',
#    'link': 'https://www.linkedin.com/posts/natalia-bourges-7094325a_canyon-activity-7064555806603538432-z2-U',
#    'activity_status': 'Gemarkeerd als interessant door Gustavo Juárez Ugarte'}],
#  'similarly_named_profiles': [],
#  'articles': [],
#  'groups': [{'profile_pic_url': 'https://media.licdn.com/dms/image/v2/C4D07AQEqlyNYz4ovGw/group-logo_image-shrink_48x48/group-logo_image-shrink_48x48/0/1631358431312?e=1728374400&v=beta&t=XVLy-7KpGFw_tZbpu0kyMd3qX834Hm9-howbwSfLp_A',
#    'name': 'Energy Professionals',
#    'url': 'https://www.linkedin.com/groups/2747'},
#   {'profile_pic_url': 'https://media.licdn.com/dms/image/v2/C5107AQHKF1oeRy7C-w/group-logo_image-shrink_48x48/group-logo_image-shrink_48x48/0/1631402074790?e=1728374400&v=beta&t=sQeogB6YhQG2iCdL43AwnI--j2rJIj-sdl-ZRBufuj4',
#    'name': 'Dutch Automotive Jobs',
#    'url': 'https://www.linkedin.com/groups/4231473'}],
#  'skills': [],
#  'inferred_salary': None,
#  'gender': None,
#  'birth_date': None,
#  'industry': None,
#  'extra': None,
#  'interests': [],
#  'personal_emails': [],
#  'personal_numbers': []}

# %%
company_profile
# Out:
# {'linkedin_internal_id': '3129165',
#  'description': 'FinTech Collective is a global, early stage venture capital firm backing entrepreneurs who are rewiring the way money moves through the world. Founded in 2012 with offices in New York City and London, the firm has deep experience investing across capital markets, wealth and asset management, banking, lending, payments, insurance, and DeFi. The managing partners of FinTech Collective met in their mid 20’s and helped build, scale, and successfully exit four fintech businesses. \n\nBacked by some of the world’s leading institutional investors, FinTech Collective manages over $800m in regulatory assets. Over the last decade the firm has had 10 exits, taken one company from pitch deck to public markets and invested in 96 portfolio companies including well known firms such as Anyfin in Stockholm, Flutterwave in Lagos, IMMO in London, Minu in Mexico City, Mondu in Berlin, Simetrik in Columbia, and several important businesses in NYC including MoneyLion, NYDIG, Ocrolus, Quovo (acquired by Plaid) and Vestwell.\n\nThe firm publishes a weekly newsletter, delivered every Saturday, which provides a tightly edited rundown of global fintech news, along with a bit of original analysis (available at fintech.io/newsletter).',
#  'website': 'http://fintech.io',
#  'industry': 'Venture Capital and Private Equity Principals',
#  'company_size': [11, 50],
#  'company_size_on_linkedin': 19,
#  'hq': {'country': 'US',
#   'city': 'New York',
#   'postal_code': '10003',
#   'line_1': '200 Park Avenue South',
#   'is_hq': True,
#   'state': 'New York'},
#  'company_type': 'PRIVATELY_HELD',
#  'founded_year': 2012,
#  'specialities': ['Financial Technology',
#   'Venture Capital',
#   'Startups',
#   'Entrepreneurs',
#   'Capital Markets',
#   'Banking',
#   'Insurance',
#   'Payments',
#   'Alternative Lending',
#   'Cryptocurrency',
#   'Wealth Management',
#   'Blockchain',
#   'Digital Assets',
#   'Emerging Markets',
#   'Impact',
#   'Fintech',
#   'Global',
#   'Africa',
#   'Latam',
#   'Europe',
#   'US'],
#  'locations': [{'country': 'US',
#    'city': 'New York',
#    'postal_code': '10003',
#    'line_1': '200 Park Avenue South',
#    'is_hq': True,
#    'state': 'New York'}],
#  'name': 'FinTech Collective',
#  'tagline': 'Backing creators with a hunger to reimagine the way money flows in a digital world.',
#  'universal_name_id': 'fintech-collective',
#  'profile_pic_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/company/fintech-collective/profile?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20240930%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20240930T032445Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=99babcd52c32be8b1574265c4f87817bdd0140c7917150035b6183d04a114cd6',
#  'background_cover_image_url': 'https://s3.us-west-000.backblazeb2.com/proxycurl/company/fintech-collective/cover?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=0004d7f56a0400b0000000001%2F20240930%2Fus-west-000%2Fs3%2Faws4_request&X-Amz-Date=20240930T032445Z&X-Amz-Expires=3600&X-Amz-SignedHeaders=host&X-Amz-Signature=5cfe2fef5455bdab5cf507c006b46878ac15afef9c412b16263ab53fcd3ecc4b',
#  'search_id': '3129165',
#  'similar_companies': [{'name': 'bunch',
#    'link': 'https://www.linkedin.com/company/bunchcapital/',
#    'industry': 'Financial Services',
#    'location': None},
#   {'name': 'WheeKeep',
#    'link': 'https://www.linkedin.com/company/wheekeep/',
#    'industry': 'Transportation, Logistics, Supply Chain and Storage',
#    'location': None},
#   {'name': 'Motive Ventures',
#    'link': 'https://www.linkedin.com/company/motiveventures/',
#    'industry': 'Venture Capital and Private Equity Principals',
#    'location': None},
#   {'name': 'Fintech Ventures Fund',
#    'link': 'https://www.linkedin.com/company/fintech-ventures-fund/',
#    'industry': 'Venture Capital and Private Equity Principals',
#    'location': None},
#   {'name': 'Cherry Ventures',
#    'link': 'https://www.linkedin.com/company/cherry-ventures/',
#    'industry': 'Venture Capital and Private Equity Principals',
#    'location': None},
#   {'name': 'Altos Ventures',
#    'link': 'https://www.linkedin.com/company/altos-ventures/',
#    'industry': 'Venture Capital and Private Equity Principals',
#    'location': None},
#   {'name': 'Fin Capital',
#    'link': 'https://www.linkedin.com/company/finventurecapital/',
#    'industry': 'Venture Capital and Private Equity Principals',
#    'location': None},
#   {'name': 'Kawar Group',
#    'link': 'https://www.linkedin.com/company/kawargroup/',
#    'industry': 'Investment Management',
#    'location': None},
#   {'name': 'Girls Into VC',
#    'link': 'https://www.linkedin.com/company/girlsintovc/',
#    'industry': 'Venture Capital and Private Equity Principals',
#    'location': None},
#   {'name': 'The MBA Fund',
#    'link': 'https://www.linkedin.com/company/thembafund/',
#    'industry': 'Venture Capital and Private Equity Principals',
#    'location': None},
#   {'name': 'FJ Labs',
#    'link': 'https://www.linkedin.com/company/fj-labs/',
#    'industry': 'Venture Capital and Private Equity Principals',
#    'location': None},
#   {'name': 'Jabbar Internet Group',
#    'link': 'https://www.linkedin.com/company/jabbar-internet-group/',
#    'industry': 'Venture Capital and Private Equity Principals',
#    'location': None},
#   {'name': 'Tivita',
#    'link': 'https://www.linkedin.com/company/tivita/',
#    'industry': 'Software Development',
#    'location': None},
#   {'name': 'Up&Up',
#    'link': 'https://www.linkedin.com/company/upandupco/',
#    'industry': 'Real Estate',
#    'location': None},
#   {'name': 'Avenir',
#    'link': 'https://www.linkedin.com/company/avenir-growth-capital/',
#    'industry': 'Venture Capital and Private Equity Principals',
#    'location': None},
#   {'name': 'Simetrik',
#    'link': 'https://www.linkedin.com/company/simetrikinc/',
#    'industry': 'Software Development',
#    'location': None},
#   {'name': 'Precursor Ventures',
#    'link': 'https://www.linkedin.com/company/precursor-ventures/',
#    'industry': 'Venture Capital and Private Equity Principals',
#    'location': None},
#   {'name': 'Ziina زينة',
#    'link': 'https://www.linkedin.com/company/ziina/',
#    'industry': 'Financial Services',
#    'location': None},
#   {'name': 'FENA Holdings',
#    'link': 'https://www.linkedin.com/company/fena-holdings/',
#    'industry': 'Investment Management',
#    'location': None},
#   {'name': 'Fintech Saudi | فنتك السعودية',
#    'link': 'https://www.linkedin.com/company/fintech-saudi/',
#    'industry': 'Financial Services',
#    'location': None}],
#  'affiliated_companies': [],
#  'updates': [{'article_link': 'https://www.linkedin.com/posts/fintech-collective_fintech-fintechnews-activity-7241433766861156352-UKLI',
#    'image': None,
#    'posted_on': {'day': 17, 'month': 9, 'year': 2024},
#    'text': 'While the US presidential debate may have been the major headline of the week, we aren’t the only country with contentious policy divides at home.\xa0Also hot off the press is the UK’s debt dilemma.\xa0In the next half century, the ratio of public debt to GDP is projected to climb to nearly 275%, vs 100% now. In addition to the widely accepted impacts that productivity and an aging population will have on the public debt outlook,\xa0another theme has been thrown into the mix: climate.\n\xa0\nThis time though, the datapoints are as concrete as an aging population.\xa0Damage related to climate change is a major contributor to the outlook over the next 50 years, with the potential to drive up debt by 20-25% of GDP, even if global temperature increases are capped at 2 degrees Celsius. If temperatures rise by up to 3 degrees though, debt could swell by 33% of GDP – at least – as the Office for Budget Responsibility highlighted a "considerable" risk that the actual costs might be significantly higher.\n\xa0\nClimate has been a notoriously partisan issue, but as the links to the economy become more and more tangible\xa0there may be less room for ‘alternative facts’ on both sides of the pond.\n\nFeatured Companies: MoneyLion, Axoni, Coincover, mattilda.\nhttps://bit.ly/3zp2bb9\n#fintech #fintechnews',
#    'total_likes': 1},
#   {'article_link': 'https://www.linkedin.com/posts/fintech-collective_fintech-fintechnews-activity-7236722194402193408-HH01',
#    'image': None,
#    'posted_on': {'day': 9, 'month': 9, 'year': 2024},
#    'text': 'During a week where it feels like the world economy rests on Nvidia’s earnings (Nvidia’s earnings have been reported to have the same impact on markets as US jobs figures), the Magnificent 7 stocks continue to be top of mind. But it would appear that\xa0the opportunity set extends far beyond the U.S. - the emerging markets are back.\n\xa0\nIn the 2000s,\xa0the economic growth of emerging markets was first coined the “rise of the rest.”\xa0But by the early 2010s, it was clear that the world was back in an era of U.S. centric growth. That landscape is subtly changing again today.\xa0\n\xa0\nThematically,\xa0many emerging market economies are well poised to serve the wave of AI application driven needs\xa0- Taiwan in semiconductors, Malaysia in data centers and Mexico for nearshoring capabilities given its proximity to the U.S. If met, this wave of demand is likely to create new pools of profit in emerging economies. In short - just like a celebrity emerging from filtering drinking water through their underwear with Bear Grylls on the side of a wet mountain -\xa0from the depths they emerge!\n\nFeatured Companies: Flutterwave, Simetrik, MoneyLion, Performativ - Wealth Management Software \nhttps://bit.ly/4g6SmiD\n#fintech #fintechnews',
#    'total_likes': 6},
#   {'article_link': 'https://www.linkedin.com/posts/fintech-collective_fintech-fintechnews-activity-7233836143757185024-r8DI',
#    'image': None,
#    'posted_on': {'day': 2, 'month': 9, 'year': 2024},
#    'text': "Apple's recent decision to open its tap-to-pay technology to third-party developers is set to reshape what's possible with an iPhone!\xa0In the beta version of iOS 18.1, developers in key markets like the US and UK will gain access to the iPhone's NFC chip and Secure Element via APIs, a feature previously restricted to Apple Wallet and Apple Pay.\xa0This move, prompted by regulatory pressure from US and EU authorities, could spur a wave of innovation, with Circle’s CEO Jeremy Allaire tweeting, “Wallet devs, start your engines” on the back of the announcement from Apple. \n\nIn opening up the APIs, developers will likely be able to innovate in more ways than just payments. \n\nOne particularly exciting frontier beyond payments lies in Decentralized Identity (DID) systems, where Apple’s Secure Element could play a pivotal role.\xa0Imagine a world where your iPhone securely manages your identity, allowing you to verify your age or the validity of your driver’s license with a simple tap without revealing unnecessary personal details like your address, actual date of birth, or social security number.\xa0Magic indeed… Unless you are a 17-year-old aspiring clubber trying to get into the KitKat club in Berlin!\n\nFeatured Companies: minka_, Flutterwave, Vestwell, Grâce\nhttps://bit.ly/3MmXlya \n#fintech #fintechnews",
#    'total_likes': 5},
#   {'article_link': 'https://www.linkedin.com/posts/fintech-collective_24fintech-activity-7235318737489309696-m2_8',
#    'image': None,
#    'posted_on': {'day': 2, 'month': 9, 'year': 2024},
#    'text': 'For those in Riyadh next week, we are excited to have Faisal Kawar participating on several different panels - see below for more details and please reach out!',
#    'total_likes': 5},
#   {'article_link': 'https://www.linkedin.com/posts/fintech-collective_fintech-fintechnews-activity-7238897615747129346-SeOV',
#    'image': None,
#    'posted_on': {'day': 16, 'month': 9, 'year': 2024},
#    'text': "Soaring rents have been squeezing renters nationwide,\xa0rising over 25% since the pandemic began—especially in fast-growing cities like Miami and Phoenix. As Americans struggle to afford housing, the US Department of Justice is stepping in, accusing RealPage, a property management software, of enabling price-fixing among landlords through its AI-driven pricing tools. \n\nThe DOJ claims that RealPage's algorithm, by gathering confidential data from landlords, allows for coordinated rent hikes,\xa0undermining competition and harming millions of renters.\xa0The machine learning system evaluates competitors' data and suggests prices based on that input, which the DOJ claims restricts independent price competition—effectively turning private data sharing into a tool for illegal coordination.\n\nIn an age where AI and real-time data are shaping nearly every industry,\xa0pricing decisions have become more dynamic than ever.\xa0This trend extends beyond rent; even something as seemingly trivial as the cost of a cocktail, or as we wrote about previously, the cost of a cheeseburger (Fast Food to Fintech). As we prepare for the US Open final this Sunday, we wonder how many Honey Deuce cocktails will be sold. The price of this iconic drink has outpaced inflation in recent years, prompting many to ask: who truly sets the cost and\xa0what could happen if AI begins to dictate pricing based on real-time consumer data?\n\nFeatured Companies: Vestwell, Ziina زينة, Fondeadora, Centrifuge, minu, Flutterwave\nhttps://bit.ly/4e7rTjm\n#fintech #fintechnews",
#    'total_likes': 4},
#   {'article_link': 'https://www.linkedin.com/posts/fintech-collective_beyond-activity-7242594247214780417-X12u',
#    'image': None,
#    'posted_on': {'day': 20, 'month': 9, 'year': 2024},
#    'text': "Since our first visit to the Kingdom of Saudi Arabia in 2016, FinTech Collective has been deeply committed to the region’s transformative journey. This week, we had the privilege of co-hosting an event in Riyadh with 24 Fintech titled “Shaping the Future of Financial Services in MENA,” we were honored to kick it off with a keynote from His Excellency Yazeed Al-Nafjan, CFA\n\nWe were joined by a fantastic audience of senior representatives from the Saudi Central Bank – SAMA , the Capital Market Authority, key leaders from local financial services firms, investors, and entrepreneurs driving innovation in the space.\n\nOur outstanding portfolio companies qlub, Pemo, WheeKeep, and Ziina زينة all helped steer insightful discussions across three critical areas:\n\n1) Building a Global Fintech Company from MENA: Exploring the opportunities and challenges of scaling fintech from the region to the world.\n2) SAMA’s Role in the KSA Ecosystem: Understanding how Saudi Arabia’s regulatory environment shapes fintech's future.\n3) Attracting Foreign Investors to MENA: We discussed how we created a first-of-its-kind framework, adapting standard U.S. and U.K. venture capital documents to align with KSA’s local legal requirements.\n\nIt was a remarkable day of thought leadership, collaboration, and a shared vision for the future of financial services in KSA and the broader Gulf Cooperation Council (GCC) region. As our colleagues Jean Abillama, CFA, Faisal Kawar, and Zein Dayekh would say.. Yalla 🚀 🚀 🚀",
#    'total_likes': 9}],
#  'follower_count': 11210,
#  'acquisitions': None,
#  'exit_data': None,
#  'extra': None,
#  'funding_data': [],
#  'categories': None,
#  'customer_list': None}

# %%
# Usecase 1 - My Case

prompt = f"""You are a professional B2B outboubd sales rep with 10 years of experience in crafting cold outreach messages that convert.
Help me write a cold outreach message for a potential partner that will make them interested in conversation.
I will give you:
1) Information about the lead we are reaching out to
2) My objective and requirements for this cold outreach
3) Example messages
Then you will:
1) Brainstorm
2) Write high-quality messages

Information about the lead we are reaching out to:
Lead's Name: {person_profile['full_name']}
Occupation: {person_profile['occupation']}
Summary: {person_profile['summary']}
Information about their company:
Company Name: {company_profile['name']}
Industry: {company_profile['industry']}
Description: {company_profile['description']}

My objective and requirements for this cold outreach:
I'm an agency owner, we specialize in providing AI automations for businesses. I just want to start a conversation, not trying to get a meeting or to sell something immeditately.
I want to spark a conversation about their company and the potential upside of using AI in their business. Because nowadays many people understand that AI might benefit their business hugely.
Right now we're focused on reaching out financial companies, here is the list of potential AI solutions for them:
1. Analysing the data from selected sources on the internet fast (like twitter, news outlets, …) in relations to specific assets
2. Due diligence: analysing specific company documents and making a standartized overview, when considering to invest in
3. Real-time monitoring the yield of different assets and providing suggestions on where to shift the liquidity
4. AI multi-agents to automate any part of the employee's pipeline
5. Regulatory reporting - AI can gather a report and your employee will only need to review it
6. Client relations and investor updates - investor can receive auto generated reports
7. Automated pitch-decks screening and evaluation for VC funds
How to write the message:
- It's a LinkedIn message, so include Subject and Body.
- GENERATE 1 FOLLOW-UP MESSAGE AS WELL.
- Keep messages short and to the point, ideally not more than 100 words.
- Make an attention-grabbing opening, so the lead can't help but read it.
- USE THE MOST SIMPLE ENGLISH WORDS THAT EVERY NON-NATIVE KNOWS.
- WRITE SIMPLE, SHORT SENTENCES.
- USE EXECATLY THE STYLE THAT I PROVIDED IN THE EXAMPLES.
- MAKE THE MESSAGE LOOK A BIT WEIRD. IMPERFECT.
- BE ULTRA SPECIFIC IN EVERY SENTENCE, AVOID VAGUE WORDS OR IDEAS. AI IS A VERY VAGUE CONCEPT, BE SPECIFIC.
- USE LOWERCASE LETTERS EVERYWHERE EXCEPT FOR NAMES.

Example messages:

Example 1

Subject: how can AI help SoundCapital make more money?

Body: hi Jacob, you seem to be an experienced hedge fund manager, have your team tried to use AI to optimize the process of company's docs review? when considering a potential investment.
I'm curious and open to talk to about potential business optimizations using AI, using multi-agents to automate a part of the employee's work, automated regulatory reporting, and many more, I think you know better.

Follow-up: or did you find AI to be worthless and you're happy to run the operations without it?

Example 2

Subject: smart VC funds use AI in their day-to-day

Body: hi Mason, I appreciate you path as a venture capitalist, do you know by any chance how VCs can become more efficient using AI?
one of the ideas that came to my mind: automated pitch-decks screening and evaluation. AI can do that pretty well, using both text and vision.
I'm just curious and looking for people eager to optimize their business with AI.

Follow-up: Mason, don't you want to make your employees more efficient using AI?

Example 3

Subject: fire your employees if they don't use AI at least 20% of their time

Body: hi Bill, you have an impressive trading background, are your employees aware about the latest AI and how they can optimize their work?
if your emoloyee manages a portfolio, they can use a custom tailored AI to analyse the relevant data 3x faster.
everyone can use ChatGPT from OpenAI's website, but that just a surface level thing and to optimize operations big time the approach has to be deeper.

Follow-up: hope you're doing awesome, Bill. so what do you think? AI is going exponentially further while the majority pretends like nothing happens.


Requirements once again:
- It's a LinkedIn message, so include Subject and Body.
- GENERATE 1 FOLLOW-UP MESSAGE AS WELL.
- Keep messages short and to the point, ideally not more than 100 words.
- Make an attention-grabbing opening, so the lead can't help but read it.
- USE THE MOST SIMPLE ENGLISH WORDS THAT EVERY NON-NATIVE KNOWS.
- WRITE SIMPLE, SHORT SENTENCES.
- USE EXECATLY THE STYLE THAT I PROVIDED IN THE EXAMPLES.
- MAKE THE MESSAGE LOOK A BIT WEIRD. IMPERFECT.
- BE ULTRA SPECIFIC IN EVERY SENTENCE, AVOID VAGUE WORDS OR IDEAS. AI IS A VERY VAGUE CONCEPT, BE SPECIFIC.
- USE LOWERCASE LETTERS EVERYWHERE EXCEPT FOR NAMES.

That's all, now it's your turn to work. Here are the steps: 1) Brainstorm how to write a catchy beginning of the message, 2) Brainstorm personalization ideas specifically to this lead, 3) Write 3 highly diverse options for the cold outreach messages in the following format:
--- Best Options ---
Option 1\n\nOption 2\n\nOption 3
And nothing else after the last option.
Your work, write the whole process here:"""

completion = openai_client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": prompt,
        }
    ],
    model="gpt-4-turbo",
)
message = completion.choices[0].message.content
print(message)
# Out:
# --- Best Options ---
# Option 1
#
# Subject: gareth, ever thought of AI revolutionizing FinTech Collective?
#
# Body: hi Gareth, noticed your work in venture capital, especially at FinTech Collective. how about utilizing AI to assess rapid data on asset trends or auto-evaluating pitch decks? imagine the time saved. curious to discuss how these specific AI tools can streamline operations within your firm.
#
# Follow-up: wondering if you’d considered what specific AI applications could do for FinTech Collective? or are manual methods still preferable?
#
# Option 2
#
# Subject: is FinTech Collective harnessing AI yet, Gareth?
#
# Body: hi Gareth, with your impactful trail in steering high-growth tech businesses, I was thinking how AI might amplify your venture’s efficiency - like automated due diligence for investments or real-time asset yield monitoring. let's chat?
#
# Follow-up: gareth, intrigued if AI could refine your investment strategies at FinTech Collective? or is it all buzz with no real bite?
#
# Option 3
#
# Subject: AI & venture capital: game-changers at FinTech Collective?
#
# Body: hi Gareth, your venture’s success in fintech caught my eye. ever considered enhancing it further with AI? think - automated document analysis, efficient liquidity management, investor auto-reports. worth discussing?
#
# Follow-up: hey Gareth, any thoughts on introducing AI tools to elevate your venture strategy, or keeping things traditional?

# %%
# Usecase 2 - Recruitment

work_experience = ''
for i in range(min(2, len(person_profile['experiences']))):
    q = person_profile['experiences'][i]
    for el in q:
        if q[el] is None:
            q[el] = 'None'
    work_experience += f"Company: {q['company']}, Role: {q['title']}, Description: {q['description']}\n"

prompt = f"""You are a professional recruiter with 10 years of experience in crafting cold outreach messages to people that you wanna hunt that convert.
Help me write a cold outreach message for a potential candidate that will make them interested in conversation.
I will give you:
1) Information about the lead we are reaching out to
2) My objective and requirements for this cold outreach
3) Example messages
Then you will:
1) Brainstorm
2) Write high-quality messages

Information about the lead we are reaching out to:
Name: {person_profile['full_name']}
Occupation: {person_profile['occupation']}
Summary: {person_profile['summary']}
Work experience:
{work_experience}

My objective and requirements for this cold outreach:
I'm a tech recruiter, I'm responsible for hiring the best talent for my company. I just want to start a conversation, and make the lead interested in the offered position.
Here is more information about our company and opened position:
Company: Jane Street. Position: Quantitative Researcher, Trading and Research. Location: London. Description: At Jane Street, we consider trading and programming to be two ends of a continuum. As both a trading firm and a tech firm, we have room for people who love to trade, people who love to program, and people everywhere in between. Nearly all of our traders write code, and many of our software engineers trade. The role you carve out for yourself will be largely dependent on your strengths and the types of problems you enjoy thinking about.
Researchers at Jane Street are responsible for building models, strategies, and systems that price and trade a variety of financial instruments. As a mix of the trading and software engineering roles, this work involves many things: analysing large datasets, building and testing models, creating new trading strategies, and writing the code that implements them.
Requirements
Be able to apply logical and mathematical thinking to all kinds of problems. Asking great questions is more important than knowing all the answers.
Write great code. We mostly write in OCaml, so you should want to learn functional programming if you don't already have experience with it.
Have good taste in research. The problems we work on rarely have clean, definitive answers. You should be comfortable pushing in new and unknown directions while maintaining clarity of purpose
Think and communicate precisely and openly. We believe great solutions come from the interaction between diverse groups of people across the firm
Fluency in English required.
How to write the message:
- It's a LinkedIn message, so include Subject and Body.
- Keep messages short and to the point, ideally not more than 100 words.
- Make an attention-grabbing opening, so the lead can't help but read it.
- MAKE AN ATTENTION-GRABBING OPENING, SO THE LEAD CAN'T HELP BUT READ IT.
- MAKE THE MESSAGE STAND OUT. OUR RECIPIENT GETS HUNDREDS OF MESSAGES DAILY.
- USE EXECATLY THE STYLE THAT I PROVIDED IN THE EXAMPLES.

Example messages:

Example 1

Subject: Mark, you deserve higher salary, and better work environment

Body: hey Mark, stumbled upon your background and couldn't help but get a bit geeky-excited at the Django-to-Kubernetes spectrum you've mastered! we're ITkey, a player in OpenStack solutions, and we're on the hunt for a Python Developer. your skills in Python, FastAPI, and Kubernetes are right up our alley. 
how about swapping your current scenery with large-scale, high-load projects and a team of top-tier professionals?


That's all, now it's your turn to work. Write 3 highly diverse options for the cold outreach messages for our lead in the following format:
Option 1\n\nOption 2\n\nOption 3
And nothing else after the last option.
Your work:"""

completion = openai_client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": prompt,
        }
    ],
    model="gpt-4-turbo",
)
message = completion.choices[0].message.content
print(message)
# Out:
# Option 1
#
# Subject: Roman, Is It Time to Explore New Frontiers in Quantitative Research?
#
# Body: Hi Roman, your expertise in LLMs at NVIDIA captures exactly the innovative spirit we value at Jane Street. We blend trading with tech seamlessly, and I believe a sharp mind like yours could make waves in our Quantitative Research team in London. Keen to discuss how your deep learning mastery could redefine trading strategies? Let's chat!
#
# Option 2
#
# Subject: Transform Trading with Your Deep Learning Expertise, Roman?
#
# Body: Hello Roman, I noticed your groundbreaking work with LLMs at NVIDIA and Stochastic. At Jane Street, we're pushing the boundaries of finance by integrating tech and trading. Your skill set is perfect for a unique Quantitative Researcher role we have in London. Interested in taking a closer look at what merging your AI experience with our trading models might look like?
#
# Option 3
#
# Subject: Roman, Can Your AI Prowess Enhance How We Trade at Jane Street?
#
# Body: Hi Roman, your work on implementing state-of-the-art LLMs caught my eye! At Jane Street, we thrive at the intersection of technology and trading—areas where your passions could greatly influence our strategies in London. Wonder how your ideas could impact financial models and trading systems? I’d love to dive into this with you!

# %%
# Usecase 3 - B2B Sales

prompt = f"""You are a professional B2B sales rep with 10 years of experience in crafting cold outreach messages that convert. You worked with billion-dollar clients like Google, Apple, and Facebook.
Help me write a cold outreach message for a potential client that will make them interested in conversation.
I will give you:
1) Information about the lead we are reaching out to
2) My objective and requirements for this cold outreach
3) Example messages
Then you will:
1) Brainstorm
2) Write high-quality messages

Information about the lead we are reaching out to:
Lead's Name: {person_profile['full_name']}
Occupation: {person_profile['occupation']}
Summary: {person_profile['summary']}
Information about their company:
Company Name: {company_profile['name']}
Industry: {company_profile['industry']}
Description: {company_profile['description']}

My objective and requirements for this cold outreach:
My name is Jason, I'm a CEO of a company called Fluently, it's an AI English coach. Fluently delivers instant feedback on your daily video calls, so you can master English every day. 
Our app helps non-native English speakers improve their language skills by providing feedback on pronunciation, grammar and vocabulary after their daily video calls.
Right now we're focused on reaching out big international companies.
How to write the message:
- It's a LinkedIn message, so include Subject and Body.
- Keep messages short and to the point, ideally not more than 100 words.
- Make an attention-grabbing opening, so the lead can't help but read it.
- USE THE MOST SIMPLE ENGLISH WORDS.
- WRITE SIMPLE, SHORT SENTENCES.
- USE EXECATLY THE STYLE THAT I PROVIDED IN THE EXAMPLES.

Example messages:

Example 1

Subject: Exploring Synergies in [Prospect's Industry]

Body: Hi [Prospect's Name],
I hope this message finds you well. I recently came across your profile while researching leaders in the [Prospect's Industry], and I was impressed by your work at [Prospect's Company].
At [Your Company], we specialize in [Your Company's Solution], which has helped companies like [Example Company] achieve [Specific Benefit/Result]. Given your focus on [Prospect's Area of Interest], I believe there might be a valuable opportunity for us to collaborate.
Would you be open to a brief call to explore how we can support your goals at [Prospect's Company]? I'm available for a call next week and would love to hear your thoughts.
Looking forward to the possibility of working together.
Best regards,
Jason, CEO, Fluently


That's all, now it's your turn to work. Write 3 highly diverse options for the cold outreach messages for our lead in the following format:
Option 1\n\nOption 2\n\nOption 3
And nothing else after the last option.
Your work:"""

print(prompt)

completion = openai_client.chat.completions.create(
    messages=[
        {
            "role": "user",
            "content": prompt,
        }
    ],
    model="gpt-4-turbo",
)
message = completion.choices[0].message.content
print(message)
# Out:
# You are a professional B2B sales rep with 10 years of experience in crafting cold outreach messages that convert. You worked with billion-dollar clients like Google, Apple, and Facebook.
# Help me write a cold outreach message for a potential client that will make them interested in conversation.
# I will give you:
# 1) Information about the lead we are reaching out to
# 2) My objective and requirements for this cold outreach
# 3) Example messages
# Then you will:
# 1) Brainstorm
# 2) Write high-quality messages
#
# Information about the lead we are reaching out to:
# Lead's Name: Gareth Jones
# Occupation: Co-Founder at FinTech Collective
# Summary: Gareth is a successful Adventurer, Entrepreneur and Business leader who has worked in emerging and high-growth technology businesses for the last twenty three years.
# Information about their company:
# Company Name: FinTech Collective
# Industry: Venture Capital and Private Equity Principals
# Description: FinTech Collective is a global, early stage venture capital firm backing entrepreneurs who are rewiring the way money moves through the world. Founded in 2012 with offices in New York City and London, the firm has deep experience investing across capital markets, wealth and asset management, banking, lending, payments, insurance, and DeFi. The managing partners of FinTech Collective met in their mid 20’s and helped build, scale, and successfully exit four fintech businesses.
#
# Backed by some of the world’s leading institutional investors, FinTech Collective manages over $800m in regulatory assets. Over the last decade the firm has had 10 exits, taken one company from pitch deck to public markets and invested in 96 portfolio companies including well known firms such as Anyfin in Stockholm, Flutterwave in Lagos, IMMO in London, Minu in Mexico City, Mondu in Berlin, Simetrik in Columbia, and several important businesses in NYC including MoneyLion, NYDIG, Ocrolus, Quovo (acquired by Plaid) and Vestwell.
#
# The firm publishes a weekly newsletter, delivered every Saturday, which provides a tightly edited rundown of global fintech news, along with a bit of original analysis (available at fintech.io/newsletter).
#
# My objective and requirements for this cold outreach:
# My name is Jason, I'm a CEO of a company called Fluently, it's an AI English coach. Fluently delivers instant feedback on your daily video calls, so you can master English every day.
# Our app helps non-native English speakers improve their language skills by providing feedback on pronunciation, grammar and vocabulary after their daily video calls.
# Right now we're focused on reaching out big international companies.
# How to write the message:
# - It's a LinkedIn message, so include Subject and Body.
# - Keep messages short and to the point, ideally not more than 100 words.
# - Make an attention-grabbing opening, so the lead can't help but read it.
# - USE THE MOST SIMPLE ENGLISH WORDS.
# - WRITE SIMPLE, SHORT SENTENCES.
# - USE EXECATLY THE STYLE THAT I PROVIDED IN THE EXAMPLES.
#
# Example messages:
#
# Example 1
#
# Subject: Exploring Synergies in [Prospect's Industry]
#
# Body: Hi [Prospect's Name],
# I hope this message finds you well. I recently came across your profile while researching leaders in the [Prospect's Industry], and I was impressed by your work at [Prospect's Company].
# At [Your Company], we specialize in [Your Company's Solution], which has helped companies like [Example Company] achieve [Specific Benefit/Result]. Given your focus on [Prospect's Area of Interest], I believe there might be a valuable opportunity for us to collaborate.
# Would you be open to a brief call to explore how we can support your goals at [Prospect's Company]? I'm available for a call next week and would love to hear your thoughts.
# Looking forward to the possibility of working together.
# Best regards,
# Jason, CEO, Fluently
#
#
# That's all, now it's your turn to work. Write 3 highly diverse options for the cold outreach messages for our lead in the following format:
# Option 1
#
# Option 2
#
# Option 3
# And nothing else after the last option.
# Your work:
# Option 1
#
# Subject: Elevate Communication at FinTech Collective
#
# Body: Hi Gareth,
# Hope you’re well. I admire how FinTech Collective is transforming finance globally, as seen in your insightful newsletter. I'm Jason, CEO at Fluently, where we enhance English proficiency for non-native speakers through AI-driven feedback on daily video calls. Considering your global team, our tool could elevate communication and efficiency. Could we discuss this potential enhancement for your team?
# Best regards,
# Jason, CEO, Fluently
#
# Option 2
#
# Subject: Perfect English for Your Global Team
#
# Body: Hello Gareth,
# Impressed by your career at FinTech Collective and its global impact. I’m Jason from Fluently - our AI tool aids non-native English speakers to perfect their language skills in routine conversations. Given your diverse international presence, this could be a game-changer. How about a quick call next week to explore synergies?
# Thanks,
# Jason, CEO, Fluently
#
# Option 3
#
# Subject: Boost Your Team’s English Fluency
#
# Body: Hi Gareth,
# I’ve been following FinTech Collective’s journey and the exciting global reach. At Fluently, we help improve English fluency daily through AI feedback. This might be a valuable add for your teams in NYC, Mexico City, Lagos, and beyond. Interested in a brief chat to discuss?
# Regards,
# Jason, CEO, Fluently

# %%
# Usecase 4 - Customer Development

prompt = f"""You are a professional B2B sales rep with 10 years of experience in crafting cold outreach messages that convert. You worked with billion-dollar clients like Google, Apple, and Facebook.
Help me write a cold outreach message for a potential client that will make them interested in conversation. It is for the customer development purposes.
I will give you:
1) Information about the lead we are reaching out to
2) My objective and requirements for this cold outreach
3) Example messages
Then you will:
1) Brainstorm
2) Write high-quality messages

Information about the lead we are reaching out to:
Lead's Name: {person_profile['full_name']}
Occupation: {person_profile['occupation']}
Summary: {person_profile['summary']}
Information about their company:
Company Name: {company_profile['name']}
Industry: {company_profile['industry']}
Description: {company_profile['description']}

My objective and requirements for this cold outreach:
My name is Pepin, I'm a CEO of a company called Annora AI, we build AI automations for manufacturing companies.
I want to know whether they have any problems that AI can solve, making them more money or saving time.
How to write the message:
- It's a LinkedIn message, so include Subject and Body.
- Keep messages short and to the point, ideally not more than 100 words.
- Make an attention-grabbing opening, so the lead can't help but read it.
- USE THE MOST SIMPLE ENGLISH WORDS.
- WRITE SIMPLE, SHORT SENTENCES.
- USE EXECATLY THE STYLE THAT I PROVIDED IN THE EXAMPLES.

Example messages:

Example 1

Subject: manufacturing companies optimize their operations with AI

Body: Hello Bobby, I appreaciate your experience in building highly efficient factories at scale.
I think AI can help you optimize some of the day-to-day processes, like customer communication or internal trainings.
Let's chat!


That's all, now it's your turn to work. Write 3 highly diverse options for the cold outreach messages for our lead in the following format:
Option 1\n\nOption 2\n\nOption 3
And nothing else after the last option.
Your work:"""

stream = openai_client.chat.completions.create(
    model="gpt-4-turbo",
    messages=[{"role": "user", "content": prompt}],
    stream=True,
)
for chunk in stream:
    if chunk.choices[0].delta.content is not None:
        print(chunk.choices[0].delta.content, end="")
# Out:
# Option 1
#
# Subject: Boost Quatt's Efficiency with AI?
#
# Body: Hello Gustavo, I'm impressed by your commitment to innovative product development in clean energy. At Annora AI, we specialize in AI solutions that streamline manufacturing processes. Could we explore how AI might enhance Quatt’s operations and speed up your growth? Let’s talk!
#
# Option 2
#
# Subject: Simplify Manufacturing at Quatt with AI
#
# Body: Hi Gustavo, your work at Quatt transforming the energy sector is inspiring. We at Annora AI help companies like yours automate and optimize manufacturing with AI. Interested in how this can save time and increase margins? Let's connect!
#
# Option 3
#
# Subject: Accelerate Quatt's Goals with AI Innovations
#
# Body: Hello Gustavo, your focus on efficient, team-driven product development at Quatt caught my eye. At Annora AI, we enhance manufacturing workflows with AI, potentially reducing costs and project timelines. Could this be a fit for Quatt? Hope to discuss soon!

# %%
s = """let's talk about ways to get more responses once people have opened your email it all comes down to what you write and what you say in that email whether they're going to respond or take the action that you want and so in order to guide you through this I've come up with seven principles of effective email copy that are going to help you write emails that stand out the first is to have a focus specific goal your goal can be getting to the next step in the funnel and starting a conversation with them and you want to keep it focused on a single outcome you want them to respond to click to intro you to somebody whatever the action is that that you want them to take and you want to focus just on that one outcome and moving them towards that action if you have multiple asks or multiple things that you want them to do in the email it can create a paradox of choice and then this feels hard and overwhelming for the recipient if they have too many things they want to do or it's not clear which is important and they're just going to either delete your email or shelf it and archive it and forget about it and move on so that's why it's really important that you have this one Focus goal and all the copy in your email should drive towards that single goal and every word counts if there's anything that doesn't move the recipient towards that goal you should delete it the second principle for writing effective emails is to be human this really helps to talk about emotions things like I'd love to it would mean a lot I'd really appreciate thanks you have no idea how much this helped because humans talk about emot and Bots or llms or whatever else you're using to try to automate this process is not good at this type of thing and it helps to be informal instead of hello or sometimes I get emails hello Mr Epstein and I don't take those very seriously versus if somebody says hey or hey Aaron and you can even have no capitalization typos can be okay these are all things that make me think that a human has written this email rather than a robot and you can even get creative with gifts or videos or other types of custom content to get people's attention and the more personalized it is the better I remember one time somebody sent me an email and in it they had an animated gift of them holding a little whiteboard and it said Aaron it had my name on it it said hi Aon and she's waving to me and so that got my attention I clicked through I wanted to see what this was about because it felt like they had done something that was very personalized that probably took time to create and that made me think that they actually cared about building a connection with me rather than just spamming thousands of people of which I was one of them and I think the main point to emphasize here is that you really want to write how you talk to a friend this is super important a lot of times people will go and they'll open up a Google doc and they'll start writing out a generic email with sequences and placeholder variables for company name and recipient name and all these things and that's not a good way to do it instead you want to open up your email editor just like you're composing an actual email to a single person put the specific person's name or email address in the two field and then write the email with that specific person in mind and I know it's tempting to use llms and other techniques to try to automate a lot of this but they often struggle with a lot of this personal connection here and then final trick here once you've written that personalized email to one specific person read it out loud either to your co-found founder if you have one or to yourself and see if it feels awkward anything that you're saying if there's something that you've written that you wouldn't feel comfortable saying out loud to somebody that's probably an indication that you should change it to be a little more human the third principle here is to personalize everyone's used to getting tons of spam and people can smell spam from a mile away so that's why personalization and making it feel targeted is super important to avoid the delete button everyone loves their name so the difference between hi there which feels generic versus hey Aaron feels like it was written for me very simple to do very simple bar across and it helps to be specific in the personalization that you're writing a lot of times I see Founders say things like hey love what you're doing at creative Market which was my startup which feels kind of generic it feels like there was a a placeholder variable for company name and they just swapped my company name in instead if somebody writes to me and they say something like I'm a huge creative Market fan ever since you launched the photos category it's now my go-to resource that shows me that the very least they've done some research on my product and the history of of what we've built and how it's evolved and at the highest level maybe they're actually a user of my product in which case I would be super excited to respond to them and get to know them so the key takeaway here is that if you're just swapping out a few words it's probably not specific enough and one really important Point here to help with personalization is you want to try to find the uncommon commonalities with the people that you're reaching out to now uncommon commonalities are things that you have uniquely in common with somebody else things that are not obvious to have in common with other people so for example if I'm reaching out to somebody and I say hey I see that you are a man I also am a man we should do business this together then they're going to be like okay that's a little weird it's a lot of people that are like that versus if somebody reaches out to me and they say hey we went to the same college and went to class in the same buildings instantly I'm starting to build a connection with them or I feel like we have something in common and I want to get to know them better and I want to help support them because I know what it's like to be in their shoes as well and it's not easy to

00:15:55	figure out what these uncommon commonalities are and so that means that you have to do the work you have to put in the work to research the company find the right contact look them up on LinkedIn use their product so you understand at a deep level how it works and then reach out to the person and that's how you're going to be able to build the deepest connections and get the most responses all right the next principle is to keep it short if you've got a wall of text that's just going to be an instant delete for most recipients

00:16:28	and really what you want to focus on on here is you want it to be short because your email will then be easy to read and respond to right away most people are pulling up emails on their phone and if you can make it so simple that they can just hit reply fire off a quick response quick a link whatever the thing is that you want they're going to do it right there in the moment if it's something that has more cognitive overhead longer to read then it means that people are going to put it on archive maybe flag it

00:16:58	to try to resp respond later or else just delete it all together and your email will be lost the fifth principle for effective cold emails is to establish credibility if you're in YC often that can be credibility enough to open doors but if you're not in YC this can be through former schools that you've attended companies that you've worked at or other impressive things that you've done you can include all of this in your email to get people to take you seriously right out of the gate also if your company is live and you have

00:17:30	customers you can share some well-known customer names as social proof in the email too if people see that either they're competitors or other well-known customer names that they know are using your product then that can provide a lot of credibility for them to get excited to use you too and if you have any interesting or useful data or Trends or anything that's industry specific that your customers might find interesting or relevant you can publish that too to help establish your yourself as an

00:18:00	expert in the space and if you have any shared connections people that you know in Comm and that sort of thing it can be great to mention that too because that'll create a baseline of trust the sixth principle here is that it's all about the reader not about you and so this means as you're writing your copy you want to reframe all the eyes as you and yours and really the trick here is to tell your story as the quest to solve the problems for your users and this works especially well if you are solving

00:18:34	a problem that you have felt yourself so for example if you know at your past company you ran into this problem it was a huge headache for you and now you're building this company to solve it you should tell the user that and tell them that you're dedicating the next 10 years of your life to build this company to solve this problem that you felt so deeply that you know that they feel too people are really going to connect if they know that you understand their problem too and they're going to want to

00:19:04	share everything with you so that you can hopefully fix it for them it's also important that you use the language that your users use to describe you not necessarily how you think about how you describe your company a good trick for this is to ask your users say how would you describe my company and they'll typically tell you in a short phrase how they would describe it and and you want to take that exact phrase and use that as the language when reaching out to other customers and I would even recommend putting that exact phrase

00:19:38	right as the header on your website because the language that your users use to describe you is almost certainly the same language that's going to resonate with other people just like them and then it's important to remember you shouldn't make demands in these emails respond to me by this date or whatever you're on their time you're in their inbox and it's not their responsibility to get back to you finally the last principle number seven here is to have a clear call to action you want to end with a concrete Next Step reply to let

00:20:10	me know click here to get started Can You intro me to Aaron Or whoever you're trying to get in touch with this makes it really clear what action you want the user to take and then it's really important to make this its own paragraph make it its own Standalone sentence right before you sign off at the end often times people will scan an email get down to the end and try to figure out what is it they're asking me to do is this something that I could take care of right now in just a few seconds or is

00:20:40	this something that's going to take more time and effort in which case I'm going to have to think about it and process it some more so by ending with a clear call to action you're more likely to get somebody to take that next step all right so these are the seven principles of effective email copy have a focus specific goal be human human personalize keep it short establish credibility make sure it's all about the reader not about you and have a clear call to action and if you do all of these things the good news is you'll be

00:21:14	the top 5% of all emails that are sent and it's going to be hard for your recipients to ignore them but one email is often not enough people are busy they're out on vacation they get distracted and so you should plan to manually follow up two three four times as needed and now there's a fine line between being persistent and being annoying so you want to give it a few days between emails and also you can get creative with each follow-up I've done this in the past I was emailing somebody they weren't responding send an email subject

00:21:50	line free donuts they opened that one and I went and brought some donuts to their office to get them to talk to me so sometimes you just got to get creative and then if somebody doesn't respond don't get angry don't get frustrated nobody owes you anything here just move on you can check back in in a couple months maybe it's not a problem for them right now maybe it will be in the future all right so let's see some examples so first we're going to take a look at a couple emails that are not effective and need some work and we'll

00:22:19	critique those and then we're going to take a look at a few emails that are actually really effective and point out some of the good parts of them and it's worth noting these are actually real email emails that I have received and I'm going to be reading them out of my inbox but I'll be anonymizing some of the details to protect the innocent here all right so the first one says hi Aaron hope all is well wanted to follow up because I noticed your order processing time could be faster our company plugs

00:22:46	into your e-commerce platform to pull orders in real time and guarantees all orders are fulfilled and on their way to your customer within one day or your money back all right the problem with this is that my company sold digital design assets that were downloadable from the internet we did not ship physical products so clearly this is a company that's trying to sell me a shipment service and because this is not targeted we are never going to be their customer this could have been the most amazingly written most personalized

00:23:20	email and nothing that they could do would make me their Customer because the targeting is not right so this illustrates the importance of having really strong targeting with your emails and why that will help you see much better conversion rates all right this next one hey there hope you are doing great I've just checked your website and your audience and content look interesting to us so here's a quick question do you partner with companies or collaborate somehow to make extra bucks best in waiting for your reply PS

00:23:51	if you don't want to hear from me anymore just let me know okay a lot of problems with this one first they didn't even have my name it just says hey there so they couldn't be bo bothered to personalize with my own name so not a great start there's nothing personalized in here checked out your website your audience looks interesting to us and then I think this is their ask do you collaborate somehow to make extra bucks I don't even know what they're specifically asking for here and then finally nobody actually signed their

00:24:23	name to this email and the PS says if you don't want to hear from me anymore just let me know which is basically telling me that this is Spam they've added me to some list and now it's my responsibility to get off that list so this is an an example of an email that I could not delete fast enough okay here's the last one which I almost instantly deleted hi Aaron my name is so and so from the Philippines I saw your LinkedIn profile and took an educated guess and sending this email you don't need to

00:24:55	tell somebody um how you found their contact information that's relevant to you not relevant to them I'm a freelancer that offers contractual work to Executives all around the globe I have been helping companies since 2014 during my past jobs I was able to facilitate good business relationships I can help assist you in your sales team I hope to share my skills and expertise with you you can see that this is all about the person who's sending it not about the recipient at all basically everything about this

00:25:26	email is I I I it's it's all focused on the person who sent it not on me the recipient and why I should reach back out to this person to work with them so this is an example of not focusing on the recipient make sure it's all focused on how you can help their problems that's all they care about all right now let's take a look at some good ones that actually worked well on me and converted first one subject line go turps this was a LinkedIn message of which I respond to very few of them hope you don't mind the

00:25:58	cold reach out but saw you also spent time in Van munching Hall so I went to the University of Maryland the Maryland terapin which we call the TPS um and I actually had a number of classes in Van munching Hall on campus so right away this is somebody that it says to me um has context when I went to school likely went there themselves um we have some uncommon commonalities uh together here as a quick intro my co-founder and I are both exg googlers working together on a meeting driven task manager so this

00:26:28	tells me they're building some credibility they've worked at Google in the past makes me think maybe they're uh solid Engineers I was hoping you might help out a fellow TP and review my YC app I've already had a few friends review so it's been cleaned up significantly and this is really helpful because it tells me that they've done the work to get it to a point where they're not going to be wasting my time and that I'm going to be able to help them with the high value things not the obvious loow hanging

00:26:57	fruit if you have a few moments let me know the best email to send you the doc and thanks in advance so this is a very clear call to action share your email with me and they'll follow up with a doc that I can just leave some feedback in so this was super effective I responded to this person um when that's something that I very rarely do okay now this next example is one that I actually wrote myself uh back when we were launching creative Market Marketplace for graphic design assets and we were recruiting

00:27:27	some designers to be our first sellers on the marketplace when we open the doors want to be one of the first creative Market Sellers and start adding your stuff we're just starting to open the doors for sellers to come in and add their content to be ready on day one of launch here's a special link to start setting up your shop it's still super early in the rollout process for us so I'd love any thoughts or feedback you have on how things are working right now we're working hard to improve things

00:27:52	every day but definitely let me know if you run into any bugs weirdness or anything else you think we should know your feedback is super important to us oh and please don't share any info or screenshots about the new site and the seller terms with anyone else just yet we're inviting handpick sellers only at this point so trying to keep it super exclusive for now welcome to the club look forward to hearing your thoughts so what's interesting about this email is this is entirely a templated email

00:28:21	except for the person's first name and the special URL that they need to come and sign up early but I use use a lot of tricks throughout in order to make it feel very special and personalized so for one it's bunch of smiley faces you know makes it feel a little more informal um I write how I talk you know it's like oh and please don't share any info that sort of thing I also use the word special and make it feel exclusive a lot here's a special link it's super early for us i' love your feedback we're

00:28:54	working hard to make it better um don't share anything because you know we're inviting handpick people only at this point it's exclusive welcome to the club so it makes it feel very special for the recipient rather than something that I'm spamming out to everybody and hoping anyone responds to me okay and this last email is going to be a little bit different we're going to do a before and after with a company that I worked with in the batch a few years back now they were uh company that sell uh in-office

00:29:24	smoothie machines and pre-made smoothies that they were trying to get startups and other companies bu subscriptions with them and so they had this email they were sending out hey we're in the current YC batch hustling to achieve our demo day goal can you forward me to your office manager to chat about trying our delicious smoothies in the office for free in exchange for feedback to improve our product we got Uber Fitbit GoPro and others using us and thought your team would enjoy them too so there's some"""

# %%
t = s.split('\n')[0]
for i in s.splitlines():
    if len(i.split('\t')) > 1:
        t += i.split('\t')[1] + ' '

# %%
print(t)
# Out:
# let's talk about ways to get more responses once people have opened your email it all comes down to what you write and what you say in that email whether they're going to respond or take the action that you want and so in order to guide you through this I've come up with seven principles of effective email copy that are going to help you write emails that stand out the first is to have a focus specific goal your goal can be getting to the next step in the funnel and starting a conversation with them and you want to keep it focused on a single outcome you want them to respond to click to intro you to somebody whatever the action is that that you want them to take and you want to focus just on that one outcome and moving them towards that action if you have multiple asks or multiple things that you want them to do in the email it can create a paradox of choice and then this feels hard and overwhelming for the recipient if they have too many things they want to do or it's not clear which is important and they're just going to either delete your email or shelf it and archive it and forget about it and move on so that's why it's really important that you have this one Focus goal and all the copy in your email should drive towards that single goal and every word counts if there's anything that doesn't move the recipient towards that goal you should delete it the second principle for writing effective emails is to be human this really helps to talk about emotions things like I'd love to it would mean a lot I'd really appreciate thanks you have no idea how much this helped because humans talk about emot and Bots or llms or whatever else you're using to try to automate this process is not good at this type of thing and it helps to be informal instead of hello or sometimes I get emails hello Mr Epstein and I don't take those very seriously versus if somebody says hey or hey Aaron and you can even have no capitalization typos can be okay these are all things that make me think that a human has written this email rather than a robot and you can even get creative with gifts or videos or other types of custom content to get people's attention and the more personalized it is the better I remember one time somebody sent me an email and in it they had an animated gift of them holding a little whiteboard and it said Aaron it had my name on it it said hi Aon and she's waving to me and so that got my attention I clicked through I wanted to see what this was about because it felt like they had done something that was very personalized that probably took time to create and that made me think that they actually cared about building a connection with me rather than just spamming thousands of people of which I was one of them and I think the main point to emphasize here is that you really want to write how you talk to a friend this is super important a lot of times people will go and they'll open up a Google doc and they'll start writing out a generic email with sequences and placeholder variables for company name and recipient name and all these things and that's not a good way to do it instead you want to open up your email editor just like you're composing an actual email to a single person put the specific person's name or email address in the two field and then write the email with that specific person in mind and I know it's tempting to use llms and other techniques to try to automate a lot of this but they often struggle with a lot of this personal connection here and then final trick here once you've written that personalized email to one specific person read it out loud either to your co-found founder if you have one or to yourself and see if it feels awkward anything that you're saying if there's something that you've written that you wouldn't feel comfortable saying out loud to somebody that's probably an indication that you should change it to be a little more human the third principle here is to personalize everyone's used to getting tons ...

# %% [markdown]
# let's talk about ways to get more responses once people have opened your email it all comes down to what you write and what you say in that email whether they're going to respond or take the action that you want and so in order to guide you through this I've come up with seven principles of effective email copy that are going to help you write emails that stand out the first is to have a focus specific goal your goal can be getting to the next step in the funnel and starting a conversation with them and you want to keep it focused on a single outcome you want them to respond to click to intro you to somebody whatever the action is that that you want them to take and you want to focus just on that one outcome and moving them towards that action if you have multiple asks or multiple things that you want them to do in the email it can create a paradox of choice and then this feels hard and overwhelming for the recipient if they have too many things they want to do or it's not clear which is important and they're just going to either delete your email or shelf it and archive it and forget about it and move on so that's why it's really important that you have this one Focus goal and all the copy in your email should drive towards that single goal and every word counts if there's anything that doesn't move the recipient towards that goal you should delete it the second principle for writing effective emails is to be human this really helps to talk about emotions things like I'd love to it would mean a lot I'd really appreciate thanks you have no idea how much this helped because humans talk about emot and Bots or llms or whatever else you're using to try to automate this process is not good at this type of thing and it helps to be informal instead of hello or sometimes I get emails hello Mr Epstein and I don't take those very seriously versus if somebody says hey or hey Aaron and you can even have no capitalization typos can be okay these are all things that make me think that a human has written this email rather than a robot and you can even get creative with gifts or videos or other types of custom content to get people's attention and the more personalized it is the better I remember one time somebody sent me an email and in it they had an animated gift of them holding a little whiteboard and it said Aaron it had my name on it it said hi Aon and she's waving to me and so that got my attention I clicked through I wanted to see what this was about because it felt like they had done something that was very personalized that probably took time to create and that made me think that they actually cared about building a connection with me rather than just spamming thousands of people of which I was one of them and I think the main point to emphasize here is that you really want to write how you talk to a friend this is super important a lot of times people will go and they'll open up a Google doc and they'll start writing out a generic email with sequences and placeholder variables for company name and recipient name and all these things and that's not a good way to do it instead you want to open up your email editor just like you're composing an actual email to a single person put the specific person's name or email address in the two field and then write the email with that specific person in mind and I know it's tempting to use llms and other techniques to try to automate a lot of this but they often struggle with a lot of this personal connection here and then final trick here once you've written that personalized email to one specific person read it out loud either to your co-found founder if you have one or to yourself and see if it feels awkward anything that you're saying if there's something that you've written that you wouldn't feel comfortable saying out loud to somebody that's probably an indication that you should change it to be a little more human the third principle here is to personalize everyone's used to getting tons of spam and people can smell spam from a mile away so that's why personalization and making it feel targeted is super important to avoid the delete button everyone loves their name so the difference between hi there which feels generic versus hey Aaron feels like it was written for me very simple to do very simple bar across and it helps to be specific in the personalization that you're writing a lot of times I see Founders say things like hey love what you're doing at creative Market which was my startup which feels kind of generic it feels like there was a a placeholder variable for company name and they just swapped my company name in instead if somebody writes to me and they say something like I'm a huge creative Market fan ever since you launched the photos category it's now my go-to resource that shows me that the very least they've done some research on my product and the history of of what we've built and how it's evolved and at the highest level maybe they're actually a user of my product in which case I would be super excited to respond to them and get to know them so the key takeaway here is that if you're just swapping out a few words it's probably not specific enough and one really important Point here to help with personalization is you want to try to find the uncommon commonalities with the people that you're reaching out to now uncommon commonalities are things that you have uniquely in common with somebody else things that are not obvious to have in common with other people so for example if I'm reaching out to somebody and I say hey I see that you are a man I also am a man we should do business this together then they're going to be like okay that's a little weird it's a lot of people that are like that versus if somebody reaches out to me and they say hey we went to the same college and went to class in the same buildings instantly I'm starting to build a connection with them or I feel like we have something in common and I want to get to know them better and I want to help support them because I know what it's like to be in their shoes as well and it's not easy tofigure out what these uncommon commonalities are and so that means that you have to do the work you have to put in the work to research the company find the right contact look them up on LinkedIn use their product so you understand at a deep level how it works and then reach out to the person and that's how you're going to be able to build the deepest connections and get the most responses all right the next principle is to keep it short if you've got a wall of text that's just going to be an instant delete for most recipients and really what you want to focus on on here is you want it to be short because your email will then be easy to read and respond to right away most people are pulling up emails on their phone and if you can make it so simple that they can just hit reply fire off a quick response quick a link whatever the thing is that you want they're going to do it right there in the moment if it's something that has more cognitive overhead longer to read then it means that people are going to put it on archive maybe flag it to try to resp respond later or else just delete it all together and your email will be lost the fifth principle for effective cold emails is to establish credibility if you're in YC often that can be credibility enough to open doors but if you're not in YC this can be through former schools that you've attended companies that you've worked at or other impressive things that you've done you can include all of this in your email to get people to take you seriously right out of the gate also if your company is live and you have customers you can share some well-known customer names as social proof in the email too if people see that either they're competitors or other well-known customer names that they know are using your product then that can provide a lot of credibility for them to get excited to use you too and if you have any interesting or useful data or Trends or anything that's industry specific that your customers might find interesting or relevant you can publish that too to help establish your yourself as an expert in the space and if you have any shared connections people that you know in Comm and that sort of thing it can be great to mention that too because that'll create a baseline of trust the sixth principle here is that it's all about the reader not about you and so this means as you're writing your copy you want to reframe all the eyes as you and yours and really the trick here is to tell your story as the quest to solve the problems for your users and this works especially well if you are solving a problem that you have felt yourself so for example if you know at your past company you ran into this problem it was a huge headache for you and now you're building this company to solve it you should tell the user that and tell them that you're dedicating the next 10 years of your life to build this company to solve this problem that you felt so deeply that you know that they feel too people are really going to connect if they know that you understand their problem too and they're going to want to share everything with you so that you can hopefully fix it for them it's also important that you use the language that your users use to describe you not necessarily how you think about how you describe your company a good trick for this is to ask your users say how would you describe my company and they'll typically tell you in a short phrase how they would describe it and and you want to take that exact phrase and use that as the language when reaching out to other customers and I would even recommend putting that exact phrase right as the header on your website because the language that your users use to describe you is almost certainly the same language that's going to resonate with other people just like them and then it's important to remember you shouldn't make demands in these emails respond to me by this date or whatever you're on their time you're in their inbox and it's not their responsibility to get back to you finally the last principle number seven here is to have a clear call to action you want to end with a concrete Next Step reply to let me know click here to get started Can You intro me to Aaron Or whoever you're trying to get in touch with this makes it really clear what action you want the user to take and then it's really important to make this its own paragraph make it its own Standalone sentence right before you sign off at the end often times people will scan an email get down to the end and try to figure out what is it they're asking me to do is this something that I could take care of right now in just a few seconds or is this something that's going to take more time and effort in which case I'm going to have to think about it and process it some more so by ending with a clear call to action you're more likely to get somebody to take that next step all right so these are the seven principles of effective email copy have a focus specific goal be human human personalize keep it short establish credibility make sure it's all about the reader not about you and have a clear call to action and if you do all of these things the good news is you'll be the top 5% of all emails that are sent and it's going to be hard for your recipients to ignore them but one email is often not enough people are busy they're out on vacation they get distracted and so you should plan to manually follow up two three four times as needed and now there's a fine line between being persistent and being annoying so you want to give it a few days between emails and also you can get creative with each follow-up I've done this in the past I was emailing somebody they weren't responding send an email subject line free donuts they opened that one and I went and brought some donuts to their office to get them to talk to me so sometimes you just got to get creative and then if somebody doesn't respond don't get angry don't get frustrated nobody owes you anything here just move on you can check back in in a couple months maybe it's not a problem for them right now maybe it will be in the future all right so let's see some examples so first we're going to take a look at a couple emails that are not effective and need some work and we'll critique those and then we're going to take a look at a few emails that are actually really effective and point out some of the good parts of them and it's worth noting these are actually real email emails that I have received and I'm going to be reading them out of my inbox but I'll be anonymizing some of the details to protect the innocent here all right so the first one says hi Aaron hope all is well wanted to follow up because I noticed your order processing time could be faster our company plugs into your e-commerce platform to pull orders in real time and guarantees all orders are fulfilled and on their way to your customer within one day or your money back all right the problem with this is that my company sold digital design assets that were downloadable from the internet we did not ship physical products so clearly this is a company that's trying to sell me a shipment service and because this is not targeted we are never going to be their customer this could have been the most amazingly written most personalized email and nothing that they could do would make me their Customer because the targeting is not right so this illustrates the importance of having really strong targeting with your emails and why that will help you see much better conversion rates all right this next one hey there hope you are doing great I've just checked your website and your audience and content look interesting to us so here's a quick question do you partner with companies or collaborate somehow to make extra bucks best in waiting for your reply PS if you don't want to hear from me anymore just let me know okay a lot of problems with this one first they didn't even have my name it just says hey there so they couldn't be bo bothered to personalize with my own name so not a great start there's nothing personalized in here checked out your website your audience looks interesting to us and then I think this is their ask do you collaborate somehow to make extra bucks I don't even know what they're specifically asking for here and then finally nobody actually signed their name to this email and the PS says if you don't want to hear from me anymore just let me know which is basically telling me that this is Spam they've added me to some list and now it's my responsibility to get off that list so this is an an example of an email that I could not delete fast enough okay here's the last one which I almost instantly deleted hi Aaron my name is so and so from the Philippines I saw your LinkedIn profile and took an educated guess and sending this email you don't need to tell somebody um how you found their contact information that's relevant to you not relevant to them I'm a freelancer that offers contractual work to Executives all around the globe I have been helping companies since 2014 during my past jobs I was able to facilitate good business relationships I can help assist you in your sales team I hope to share my skills and expertise with you you can see that this is all about the person who's sending it not about the recipient at all basically everything about this email is I I I it's it's all focused on the person who sent it not on me the recipient and why I should reach back out to this person to work with them so this is an example of not focusing on the recipient make sure it's all focused on how you can help their problems that's all they care about all right now let's take a look at some good ones that actually worked well on me and converted first one subject line go turps this was a LinkedIn message of which I respond to very few of them hope you don't mind the cold reach out but saw you also spent time in Van munching Hall so I went to the University of Maryland the Maryland terapin which we call the TPS um and I actually had a number of classes in Van munching Hall on campus so right away this is somebody that it says to me um has context when I went to school likely went there themselves um we have some uncommon commonalities uh together here as a quick intro my co-founder and I are both exg googlers working together on a meeting driven task manager so this tells me they're building some credibility they've worked at Google in the past makes me think maybe they're uh solid Engineers I was hoping you might help out a fellow TP and review my YC app I've already had a few friends review so it's been cleaned up significantly and this is really helpful because it tells me that they've done the work to get it to a point where they're not going to be wasting my time and that I'm going to be able to help them with the high value things not the obvious loow hanging fruit if you have a few moments let me know the best email to send you the doc and thanks in advance so this is a very clear call to action share your email with me and they'll follow up with a doc that I can just leave some feedback in so this was super effective I responded to this person um when that's something that I very rarely do okay now this next example is one that I actually wrote myself uh back when we were launching creative Market Marketplace for graphic design assets and we were recruiting some designers to be our first sellers on the marketplace when we open the doors want to be one of the first creative Market Sellers and start adding your stuff we're just starting to open the doors for sellers to come in and add their content to be ready on day one of launch here's a special link to start setting up your shop it's still super early in the rollout process for us so I'd love any thoughts or feedback you have on how things are working right now we're working hard to improve things every day but definitely let me know if you run into any bugs weirdness or anything else you think we should know your feedback is super important to us oh and please don't share any info or screenshots about the new site and the seller terms with anyone else just yet we're inviting handpick sellers only at this point so trying to keep it super exclusive for now welcome to the club look forward to hearing your thoughts so what's interesting about this email is this is entirely a templated email except for the person's first name and the special URL that they need to come and sign up early but I use use a lot of tricks throughout in order to make it feel very special and personalized so for one it's bunch of smiley faces you know makes it feel a little more informal um I write how I talk you know it's like oh and please don't share any info that sort of thing I also use the word special and make it feel exclusive a lot here's a special link it's super early for us i' love your feedback we're working hard to make it better um don't share anything because you know we're inviting handpick people only at this point it's exclusive welcome to the club so it makes it feel very special for the recipient rather than something that I'm spamming out to everybody and hoping anyone responds to me okay and this last email is going to be a little bit different we're going to do a before and after with a company that I worked with in the batch a few years back now they were uh company that sell uh in-office smoothie machines and pre-made smoothies that they were trying to get startups and other companies bu subscriptions with them and so they had this email they were sending out hey we're in the current YC batch hustling to achieve our demo day goal can you forward me to your office manager to chat about trying our delicious smoothies in the office for free in exchange for feedback to improve our product we got Uber Fitbit GoPro and others using us and thought your team would enjoy them too so there's some good stuff in here they've got the social proof that Uber Fitbit GoPro those are logos that we recognize so it makes it seem like they're more legit but you know it's all about them trying to get their demo day goal and um you know it doesn't seem as enticing for somebody to want to try to help them out it's less clear what's in it for the recipient so after brainstorming a bit and iterating on it here's what we came up with working with the founders the subject was smoothie party current YC company hey first name I'm Oliver the founder of snack Blends from the current YC badge and I'd love to throw free Smoothie party for the whole company team at your office it's like happy hour but smoothies and free are you interested all we ask in return is for some feedback on the smoothies is there an afternoon I can come by to treat your team thanks and so when they started doing this one it almost seemed like a no-brainer for their recipients yeah free Smoothie party somebody's going to come and give smoothies to my team sounds great and so that helped get them in the door to be able to then sell those um as long term deals
